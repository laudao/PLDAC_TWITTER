# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
twitter_db = connect_to_db()

# %%
N = 1000
tweet_list = []

cursor = twitter_db.cursor()

query = ("SELECT text FROM tweets WHERE lang='fr' LIMIT " + str(N))

cursor.execute(query)

for text in cursor:
    tweet_list.append(text[0])

cursor.close()
# Out:
# True

# %%
fr_stopwords = nltk.corpus.stopwords.words('french')
fr_stopwords.extend(['de', 'ou', 'sur', 'or', 'ni', 'car', 'quand', 'a', 'mais', 'donc', 'si', 'quel', 'entre',\
                       'tout', 'ce', 'cet', 'ça', 'tous', "c'est", 'faire', 'dans', 'fait'])

# %%
[vectorizer, words_freq] = build_vectorizer(tweet_list, stopwords=fr_stopwords, b_stemming=True,b_punctuation=True, b_accent=False)
# Out:
# Stemming
# Keeping punctuation
# Removing accents

# %%
features = vectorizer.get_feature_names()
print(len(features))
print(features)
# Out:
# 670
# ['000', '05', '14', '16', '20', '2017', '21', '26', '28', '2e', '2nd', '32', '395', '46', '500', '6erepubl', '90', '91', '99', 'aberr', 'abord', 'absent', 'accord', 'achet', 'actif', 'adversair', 'affair', 'affich', 'affront', 'age', 'agit', 'agriculteur', 'aid', 'ailleur', 'aim', 'alcool', 'alianc', 'alle', 'aller', 'alli', 'allianc', 'alloc', 'alor', 'alstom', 'ambiguit', 'amnest', 'amnesty', 'amp', 'an', 'annul', 'anonym', 'antisemit', 'apparatchik', 'apparent', 'appliqu', 'approch', 'apre', 'arab', 'archiv', 'ardeur', 'argent', 'argument', 'arret', 'arri', 'arriv', 'artisan', 'asselineau2017', 'assez', 'assitanat', 'atos', 'attach', 'attaqu', 'attend', 'aucun', 'audienc', 'aunomdupeupl', 'auss', 'autoris', 'autorit', 'autr', 'avant', 'avaric', 'ave', 'aven', 'avenirencommun', 'aveugl', 'avis', 'avoir', 'bankst', 'banqu', 'barbar', 'beatitud', 'beaucoup', 'bel', 'benefic', 'besoin', 'bien', 'bolivarien', 'boob', 'bou', 'bourdin', 'brass', 'brigitt', 'bris', 'cac40', 'cach', 'cadr', 'caiss', 'calcul', 'camp', 'campagn', 'candidat', 'capabl', 'capital', 'caraib', 'cardin', 'carrier', 'celui', 'certain', 'chanc', 'chang', 'chat', 'cherch', 'chez', 'chirac', 'choix', 'chos', 'chretien', 'chut', 'cit', 'citoyen', 'clash', 'clean', 'club', 'collect', 'colonis', 'comm', 'comment', 'comorien', 'compr', 'comprend', 'comprendr', 'con', 'concentr', 'concern', 'confianc', 'conseil', 'conserv', 'constitu', 'consult', 'contr', 'contraint', 'cop', 'core', 'correct', 'corrompu', 'coup', 'couteau', 'craint', 'cre', 'credibl', 'crevent', 'cri', 'crim', 'crois', 'cru', 'culp', 'cultur', 'cupidit', 'cur', 'curieux', 'dat', 'debarr', 'decadent', 'dechir', 'defendu', 'dej', 'demago', 'demand', 'demandeur', 'democrat', 'den', 'dep', 'depensier', 'depui', 'descendon', 'design', 'detest', 'detr', 'deux', 'devan', 'deven', 'devers', 'dictateur', 'different', 'directeur', 'dis', 'discour', 'discut', 'dit', 'diver', 'divis', 'doit', 'dom', 'don', 'dos', 'droit', 'drol', 'dutroux', 'dynam', 'echeanc', 'eclat', 'econom', 'educ', 'eduqu', 'effac', 'effect', 'egard', 'eh', 'ehonte', 'ei', 'elect', 'electorat', 'electric', 'elyse', 'em', 'eminem', 'eminent', 'emmanuel', 'emmanuelholland', 'emploi', 'empris', 'emprunt', 'encor', 'enfant', 'enfumag', 'engag', 'enmarch', 'ennem', 'enormit', 'entendr', 'entrepreneur', 'entrepris', 'envi', 'envoi', 'envoyespecial', 'epoqu', 'equip', 'eric', 'escroquer', 'esper', 'etat', 'eton', 'etre', 'etudi', 'euro', 'europeen', 'evit', 'ex', 'excellent', 'excit', 'exclus', 'exil', 'experient', 'expliqu', 'exploit', 'extrem', 'eyelin', 'fac', 'factur', 'fastidi', 'fauss', 'faut', 'faveur', 'fdp', 'ferm', 'ff', 'fi', 'fictif', 'figur', 'fil', 'fillon', 'fillon2017', 'fillonment', 'fin', 'financ', 'florian', 'fn', 'fol', 'foot', 'form', 'fortun', 'foutu', 'franc', 'francais', 'franco', 'furet', 'gauch', 'gauchist', 'gaulois', 'gay', 'gen', 'general', 'gif', 'gomm', 'goss', 'gouvern', 'grac', 'grand', 'grandeur', 'guerr', 'habit', 'hain', 'ham', 'hamon', 'heur', 'hi', 'histoir', 'hold', 'holland', 'homm', 'homophob', 'homosexuel', 'htt', 'hu', 'huh', 'hui', 'humain', 'humanit', 'hysteris', 'idiot', 'imag', 'immigr', 'import', 'importan', 'impos', 'impostur', 'impot', 'in', 'influenc', 'info', 'innocent', 'instrumentalis', 'insult', 'insurrect', 'interess', 'interlocuteur', 'interpel', 'interview', 'intox', 'iran', 'issus', 'italien', 'jacqu', 'jam', 'jaun', 'jean', 'jeun', 'jevotefillon', 'jevotemacron', 'jl', 'jlm', 'jlm2', 'jlm2017', 'jlmlill', 'jlui', 'jol', 'jouent', 'jour', 'jud', 'juif', 'jul', 'jupp', 'just', 'justifi', 'lach', 'laforcedupeupl', 'larbin', 'larg', 'le79int', 'lectur', 'lepen', 'libr', 'lik', 'lillemlp', 'limit', 'lis', 'lobb', 'logiqu', 'lor', 'lr', 'lu', 'macron', 'macron2017', 'majoritair', 'malien', 'mar', 'marin', 'marine2017', 'masoch', 'match', 'matier', 'mec', 'medi', 'meeting', 'melenchon', 'membr', 'men', 'mensong', 'menteux', 'mepr', 'messag', 'met', 'mieux', 'million', 'miser', 'mlp', 'mlp2017', ...

# %%
words_freq
# Out:
# [('jam', 53),
#  ('macron', 34),
#  ('fillon', 28),
#  ('autr', 28),
#  ('propos', 26),
#  ('argent', 25),
#  ('autorit', 24),
#  ('moral', 24),
#  ('dat', 24),
#  ('insult', 24),
#  ('annul', 24),
#  ('vois', 24),
#  ('trois', 24),
#  ('melenchon', 21),
#  ('franc', 20),
#  ('plus', 19),
#  ('san', 17),
#  ('repondu', 17),
#  ('vot', 16),
#  ('excellent', 14),
#  ('not', 14),
#  ('avoir', 13),
#  ('emmanuel', 12),
#  ('alstom', 12),
#  ('2017', 11),
#  ('etre', 10),
#  ('jlm2017', 10),
#  ('droit', 10),
#  ('rien', 9),
#  ('electric', 9),
#  ('general', 9),
#  ('econom', 9),
#  ('opinion', 8),
#  ('certain', 8),
#  ('programm', 8),
#  ('educ', 7),
#  ('pretend', 7),
#  ('hamon', 7),
#  ('comm', 7),
#  ('test', 7),
#  ('emmanuelholland', 7),
#  ('question', 7),
#  ('savoir', 7),
#  ('malien', 6),
#  ('per', 6),
#  ('juif', 6),
#  ('chretien', 6),
#  ('seul', 6),
#  ('apre', 6),
#  ('comorien', 6),
#  ('bien', 6),
#  ('tre', 6),
#  ('fn', 6),
#  ('territoir', 6),
#  ('interess', 6),
#  ('cri', 6),
#  ('italien', 6),
#  ('holland', 6),
#  ('precoc', 6),
#  ('etat', 6),
#  ('hain', 6),
#  ('polit', 5),
#  ('dit', 5),
#  ('contr', 5),
#  ('model', 5),
#  ('pr', 5),
#  ('fi', 5),
#  ('alor', 5),
#  ('aucun', 5),
#  ('defendu', 5),
#  ('part', 5),
#  ('oublion', 5),
#  ('pourr', 5),
#  ('gauch', 4),
#  ('avant', 4),
#  ('bel', 4),
#  ('arab', 4),
#  ('tour', 4),
#  ('just', 4),
#  ('vu', 4),
#  ('carrier', 4),
#  ('aim', 4),
#  ('electorat', 4),
#  ('homm', 4),
#  ('an', 4),
#  ('esper', 4),
#  ('engag', 4),
#  ('lr', 4),
#  ('expliqu', 4),
#  ('celui', 4),
#  ('comment', 4),
#  ('million', 4),
#  ('jud', 4),
#  ('compr', 4),
#  ('chez', 4),
#  ('demand', 4),
#  ('rich', 4),
#  ('marin', 4),
#  ('messag', 4),
#  ('soutient', 3),
#  ('age', 3),
#  ('gaulois', 3),
#  ('craint', 3),
#  ('plein', 3),
#  ('jupp', 3),
#  ('financ', 3),
#  ('amnest', 3),
#  ('radical', 3),
#  ('doit', 3),
#  ('medi', 3),
#  ('risqu', 3),
#  ('progr', 3),
#  ('veut', 3),
#  ('cultur', 3),
#  ('pen', 3),
#  ('social', 3),
#  ('vent', 3),
#  ('necessair', 3),
#  ('jlmlill', 3),
#  ('tel', 3),
#  ('elect', 3),
#  ('mec', 3),
#  ('person', 3),
#  ('encor', 3),
#  ('mar', 3),
#  ('photos', 3),
#  ('accord', 3),
#  ('auss', 3),
#  ('2nd', 3),
#  ('quelqu', 3),
#  ('affair', 3),
#  ('peut', 3),
#  ('campagn', 3),
#  ('ardeur', 3),
#  ('matier', 3),
#  ('con', 3),
#  ('jl', 3),
#  ('non', 3),
#  ('problem', 3),
#  ('humain', 3),
#  ('vision', 3),
#  ('avis', 3),
#  ('francais', 3),
#  ('bourdin', 3),
#  ('enmarch', 3),
#  ('envoi', 3),
#  ('attaqu', 3),
#  ('tweet', 3),
#  ('jevotemacron', 3),
#  ('chos', 3),
#  ('candidat', 3),
#  ('20', 3),
#  ('sondag', 3),
#  ('descendon', 3),
#  ('mensong', 3),
#  ('cre', 3),
#  ('cach', 3),
#  ('meeting', 3),
#  ('don', 3),
#  ('pend', 3),
#  ('dej', 2),
#  ('concentr', 2),
#  ('fdp', 2),
#  ('jlui', 2),
#  ('comprendr', 2),
#  ('realit', 2),
#  ('chanc', 2),
#  ('rion', 2),
#  ('multinational', 2),
#  ('chang', 2),
#  ('different', 2),
#  ('gen', 2),
#  ('debarr', 2),
#  ('projet', 2),
#  ('nouveau', 2),
#  ('trouv', 2),
#  ('arri', 2),
#  ('tax', 2),
#  ('ennem', 2),
#  ('miser', 2),
#  ('rend', 2),
#  ('habit', 2),
#  ('brass', 2),
#  ('emploi', 2),
#  ('radicalis', 2),
#  ('2e', 2),
#  ('devan', 2),
#  ('em', 2),
#  ('conseil', 2),
#  ('eminent', 2),
#  ('siecl', 2),
#  ('extrem', 2),
#  ('surtout', 2),
#  ('exploit', 2),
#  ('import', 2),
#  ('selon', 2),
#  ('lach', 2),
#  ('in', 2),
#  ('macron2017', 2),
#  ('egard', 2),
#  ('beatitud', 2),
#  ('bolivarien', 2),
#  ('achet', 2),
#  ('sort', 2),
#  ('discut', 2),
#  ('veux', 2),
#  ('chat', 2),
#  ('mot', 2),
#  ('90', 2),
#  ('mlp', 2),
#  ('hysteris', 2),
#  ('furet', 2),
#  ('exil', 2),
#  ('normal', 2),
#  ('hi', 2),
#  ('saou', 2),
#  ('beaucoup', 2),
#  ('elyse', 2),
#  ('pot', 2),
#  ('pourt', 2),
#  ('soir', 2),
#  ('heur', 2),
#  ('president', 2),
#  ('mond', 2),
#  ('poursuit', 2),
#  ('fac', 2),
#  ('homosexuel', 2),
#  ('total', 2),
#  ('yeux', 2),
#  ('ex', 2),
#  ('strateg', 2),
#  ('tyrann', 2),
#  ('appliqu', 2),
#  ('depui', 2),
#  ('mlp2017', 2),
#  ('pro', 2),
#  ('monsieur', 2),
#  ('siffl', 2),
#  ('camp', 2),
#  ('ouvr', 2),
#  ('pouvoir', 2),
#  ('pol', 2),
#  ('pass', 2),
#  ('impot', 2),
#  ('arret', 2),
#  ('prendr', 2),
#  ('dynam', 2),
#  ('deux', 2),
#  ('ten', 2),
#  ('lepen', 2),
#  ('marine2017', 2),
#  ('comprend', 2),
#  ('eton', 2),
#  ('pai', 2),
#  ('clash', 2),
#  ('tap', 2),
#  ('tw', 2),
#  ('cadr', 2),
#  ('recent', 2),
#  ('ferm', 2),
#  ('va', 2),
#  ('aid', 2),
#  ('urgenc', 2),
#  ('crois', 1),
#  ('den', 1),
#  ('put', 1),
#  ('object', 1),
#  ('gomm', 1),
#  ('pan', 1),
#  ('quarti', 1),
#  ('issus', 1),
#  ('drol', 1),
#  ('limit', 1),
#  ('supplementair', 1),
#  ('refletent', 1),
#  ('rejoint', 1),
#  ('vall', 1),
#  ('rit', 1),
#  ('reaction', 1),
#  ('philippot', 1),
#  ('bris', 1),
#  ('fin', 1),
#  ('ultraliberal', 1),
#  ('395', 1),
#  ('ehonte', 1),
#  ('alle', 1),
#  ('05', 1),
#  ('iran', 1),
#  ('rendslargent', 1),
#  ('detest', 1),
#  ('assitanat', 1),
#  ('parj', 1),
#  ('superieur', 1),
#  ('pris', 1),
#  ('scandal', 1),
#  ('poubel', 1),
#  ('detr', 1),
#  ('faut', 1),
#  ('avenirencommun', 1),
#  ('jour', 1),
#  ('tal', 1),
#  ('patrimoin', 1),
#  ('florian', 1),
#  ('couteau', 1),
#  ('pmi', 1),
#  ('le79int', 1),
#  ('parl', 1),
#  ('caiss', 1),
#  ('system', 1),
#  ('populair', 1),
#  ('alianc', 1),
#  ('jlm', 1),
#  ('jaun', 1),
#  ('laforcedupeupl', 1),
#  ('chut', 1),
#  ('intox', 1),
#  ('vast', 1),
#  ('pratiqu', 1),
#  ('contraint', 1),
#  ('menteux', 1),
#  ('mepr', 1),
#  ('upr', 1),
#  ('cru', 1),
#  ('impos', 1),
#  ('aven', 1),
#  ('usin', 1),
#  ('culp', 1),
#  ('sembl', 1),
#  ('plac', 1),
#  ('rt', 1),
#  ('pir', 1),
#  ('experient', 1),
#  ('dep', 1),
#  ('europeen', 1),
#  ('cardin', 1),
#  ('paul', 1),
#  ('actif', 1),
#  ('pay', 1),
#  ('rhetor', 1),
#  ('union', 1),
#  ('eyelin', 1),
#  ('sarko', 1),
#  ('franco', 1),
#  ('temp', 1),
#  ('alcool', 1),
#  ('naz', 1),
#  ('interlocuteur', 1),
#  ('gauchist', 1),
#  ('directeur', 1),
#  ('respons', 1),
#  ('mort', 1),
#  ('regional', 1),
#  ('phillipot', 1),
#  ('entrepreneur', 1),
#  ('histoir', 1),
#  ('interview', 1),
#  ('veuill', 1),
#  ('emprunt', 1),
#  ('assez', 1),
#  ('alloc', 1),
#  ('aveugl', 1),
#  ('lis', 1),
#  ('antisemit', 1),
#  ('pareil', 1),
#  ('crevent', 1),
#  ('allianc', 1),
#  ('guerr', 1),
#  ('crim', 1),
#  ('constitu', 1),
#  ('adversair', 1),
#  ('standing', 1),
#  ('popul', 1),
#  ('syrien', 1),
#  ('epoqu', 1),
#  ('pens', 1),
#  ('banqu', 1),
#  ('fauss', 1),
#  ('tant', 1),
#  ('larg', 1),
#  ('instrumentalis', 1),
#  ('respect', 1),
#  ('special', 1),
#  ('travaill', 1),
#  ('99', 1),
#  ('pme', 1),
#  ('jevotefillon', 1),
#  ('club', 1),
#  ('peur', 1),
#  ('000', 1),
#  ('v', 1),
#  ('revele', 1),
#  ('vont', 1),
#  ('trich', 1),
#  ('libr', 1),
#  ('fastidi', 1),
#  ('produir', 1),
#  ('jouent', 1),
#  ('21', 1),
#  ('obj', 1),
#  ('tchetchen', 1),
#  ('pub', 1),
#  ('archiv', 1),
#  ('patrick', 1),
#  ('quatriem', 1),
#  ('jul', 1),
#  ('mois', 1),
#  ('innocent', 1),
#  ('correct', 1),
#  ('statur', 1),
#  ('46', 1),
#  ('etudi', 1),
#  ('echeanc', 1),
#  ('match', 1),
#  ('effect', 1),
#  ('prevu', 1),
#  ('dos', 1),
#  ('democrat', 1),
#  ('nord', 1),
#  ('28', 1),
#  ('rendr', 1),
#  ('mieux', 1),
#  ('barbar', 1),
#  ('evit', 1),
#  ('grandeur', 1),
#  ('agit', 1),
#  ('credibl', 1),
#  ('conserv', 1),
#  ('masoch', 1),
#  ('argument', 1),
#  ('rir', 1),
#  ('envi', 1),
#  ('dom', 1),
#  ('voul', 1),
#  ('eminem', 1),
#  ('entendr', 1),
#  ('anonym', 1),
#  ('fillon2017', 1),
#  ('logiqu', 1),
#  ('citoyen', 1),
#  ('autoris', 1),
#  ('larbin', 1),
#  ('empris', 1),
#  ('cupidit', 1),
#  ('phras', 1),
#  ('brigitt', 1),
#  ('voudr', 1),
#  ('perc', 1),
#  ('aller', 1),
#  ('escroquer', 1),
#  ('premi', 1),
#  ('sien', 1),
#  ('avaric', 1),
#  ('ump', 1),
#  ('clean', 1),
#  ('rar', 1),
#  ('transparent', 1),
#  ('core', 1),
#  ('orgueil', 1),
#  ('14', 1),
#  ('valeur', 1),
#  ('affront', 1),
#  ('photo', 1),
#  ('chirac', 1),
#  ('serieux', 1),
#  ('poutin', 1),
#  ('aberr', 1),
#  ('souhait', 1),
#  ('choix', 1),
#  ('sombr', 1),
#  ('confianc', 1),
#  ('lor', 1),
#  ('prof', 1),
#  ('envoyespecial', 1),
#  ('influenc', 1),
#  ('ovat', 1),
#  ('design', 1),
#  ('corrompu', 1),
#  ('decadent', 1),
#  ('goss', 1),
#  ('divis', 1),
#  ('diver', 1),
#  ('vrai', 1),
#  ('presidentielle2017', 1),
#  ('foot', 1),
#  ('ambiguit', 1),
#  ('ave', 1),
#  ('atos', 1),
#  ('passat', 1),
#  ('plait', 1),
#  ('redress', 1),
#  ('gif', 1),
#  ('500', 1),
#  ('euro', 1),
#  ('thevoic', 1),
#  ('pouvo', 1),
#  ('nullissim', 1),
#  ('ailleur', 1),
#  ('tr', 1),
#  ('prennent', 1),
#  ('ff', 1),
#  ('insurrect', 1),
#  ('penelop', 1),
#  ('toler', 1),
#  ('cit', 1),
#  ('publiqu', 1),
#  ('up', 1),
#  ('tl', 1),
#  ('voleux', 1),
#  ('asselineau2017', 1),
#  ('enormit', 1),
#  ('homophob', 1),
#  ('idiot', 1),
#  ('ham', 1),
#  ('foutu', 1),
#  ('faveur', 1),
#  ('ridicul', 1),
#  ('dechir', 1),
#  ('jol', 1),
#  ('enfant', 1),
#  ('nullit', 1),
#  ('partag', 1),
#  ('taxe', 1),
#  ('fil', 1),
#  ('abord', 1),
#  ('cop', 1),
#  ('absent', 1),
#  ('shit', 1),
#  ('collect', 1),
#  ('qd', 1),
#  ('lik', 1),
#  ('train', 1),
#  ('ressourc', 1),
#  ('bou', 1),
#  ('humanit', 1),
#  ('trait', 1),
#  ('approch', 1),
#  ('dis', 1),
#  ('32', 1),
#  ('lobb', 1),
#  ('dictateur', 1),
#  ('concern', 1),
#  ('sectair', 1),
#  ('demandeur', 1),
#  ('gouvern', 1),
#  ('recuper', 1),
#  ('amp', 1),
#  ('cherch', 1),
#  ('sexual', 1),
#  ('apparatchik', 1),
#  ('exclus', 1),
#  ('voudront', 1),
#  ('cac40', 1),
#  ('jean', 1),
#  ('stalin', 1),
#  ('penal', 1),
#  ('moment', 1),
#  ('amnesty', 1),
#  ('grac', 1),
#  ('hold', 1),
#  ('equip', 1),
#  ('lectur', 1),
#  ('huh', 1),
#  ('lu', 1),
#  ('devers', 1),
#  ('jlm2', 1),
#  ('apparent', 1),
#  ('calcul', 1),
#  ('pdg', 1),
#  ('rassembl', 1),
#  ('interpel', 1),
#  ('gay', 1),
#  ('revenus', 1),
#  ('audienc', 1),
#  ('bankst', 1),
#  ('jacqu', 1),
#  ('soutenu', 1),
#  ('capital', 1),
#  ('rigol', 1),
#  ('htt', 1),
#  ('figur', 1),
#  ('eric', 1),
#  ('form', 1),
#  ('cur', 1),
#  ('ose', 1),
#  ('re', 1),
#  ('majoritair', 1),
#  ('eh', 1),
#  ('oubl', 1),
#  ('16', 1),
#  ('raconte', 1),
#  ('alli', 1),
#  ('entrepris', 1),
#  ('fortun', 1),
#  ('91', 1),
#  ('imag', 1),
#  ('tj', 1),
#  ('colonis', 1),
#  ('info', 1),
#  ('oblig', 1),
#  ('suff', 1),
#  ('affich', 1),
#  ('attach', 1),
#  ('hu', 1),
#  ('eduqu', 1),
#  ('fol', 1),
#  ('boob', 1),
#  ('sent', 1),
#  ('effac', 1),
#  ('sit', 1),
#  ('deven', 1),
#  ('dutroux', 1),
#  ('26', 1),
#  ('oppos', 1),
#  ('benefic', 1),
#  ('musulman', 1),
#  ('mur', 1),
#  ('peux', 1),
#  ('immigr', 1),
#  ('coup', 1),
#  ('discour', 1),
#  ('met', 1),
#  ('tet', 1),
#  ('sarkozy', 1),
#  ('fillonment', 1),
#  ('ridiculetv', 1),
#  ('aunomdupeupl', 1),
#  ('membr', 1),
#  ('justifi', 1),
#  ('regl', 1),
#  ('rothschild', 1),
#  ('eclat', 1),
#  ('factur', 1),
#  ('depensier', 1),
#  ('caraib', 1),
#  ('men', 1),
#  ('ei', 1),
#  ('salu', 1),
#  ('jeun', 1),
#  ('importan', 1),
#  ('enfumag', 1),
#  ('arriv', 1),
#  ('sond', 1),
#  ('demago', 1),
#  ('surpris', 1),
#  ('soudain', 1),
#  ('truc', 1),
#  ('attend', 1),
#  ('rev', 1),
#  ('besoin', 1),
#  ('impostur', 1),
#  ('capabl', 1),
#  ('lillemlp', 1),
#  ('recycl', 1),
#  ('consult', 1),
#  ('artisan', 1),
#  ('fictif', 1),
#  ('6erepubl', 1),
#  ('hui', 1),
#  ('raccourc', 1),
#  ('prefer', 1),
#  ('excit', 1),
#  ('repet', 1),
#  ('promess', 1),
#  ('grand', 1),
#  ('turc', 1),
#  ('agriculteur', 1),
#  ('ogm', 1),
#  ('curieux', 1),
#  ('taub', 1),
#  ('trump', 1)]
